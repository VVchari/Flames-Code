# %%
#Enter the names
name1=input("Enter the first name:").lower()
name2=input("Enter the second name:").lower()
lst1=[]
lst2=[]
name1=name1.split(" ")
name1="".join(name1)
name2=name2.split(" ")
name2="".join(name2)
l1=len(name1)
l2=len(name2)
for n1 in range(l1):
    lst1.append(name1[n1])
for n2 in range(l2):
    lst2.append(name2[n2])
a=0
#if length of first name is large
if l1>l2:
    for m in range(l1):
        c=0
        while c<l2:
            if lst1[a]==lst2[c]:
                lst1.pop(a)
                lst2.pop(c)
                l2=len(lst2)
                c=0
                a=a-1
                break
            c=c+1
        a=a+1
#if length of second is large
else:
    for m in range(l2):
        c=0
        while c<l1:
            if lst2[a]==lst1[c]:
                lst2.pop(a)
                lst1.pop(c)
                l1=len(lst1)
                c=0
                a=a-1
                break
            c=c+1
        a=a+1
#if length of both names is same
if l1==l2:
     for m in range(l2):
        c=0
        while c<l1:
            if lst2[a]==lst1[c]:
                lst2.pop(a)
                lst1.pop(c)
                l1=len(lst1)
                c=0
                a=a-1
                break
            c=c+1
        a=a+1
l1=len(lst1)
l2=len(lst2)
l=l1+l2
f=["Friends","Love","Attraction","Marraige","Enemies","Sister"]
L=len(f)
L1=len(f)
lst=[]
j=0
for n in range(L):
    lst.append(f[n])
for k in range(L1):
    i=0
    while i<l and i!=l-1:
        if j<L and j!=L-1:
            j=j+1
            i=i+1
        else:
            j=0
            i=i+1
    if i==l-1:
        if k==L1-1:
            print(lst[j])
        lst.pop(j)
        L=len(lst)
        if j==L:
            j=0
# Out:
# Enter the first name:Vishnu
# Enter the second name:Priya
# Enemies
